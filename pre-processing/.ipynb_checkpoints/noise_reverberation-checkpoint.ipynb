# %%
import os, random
from pydub import AudioSegment
from xml.dom import minidom
import numpy as np
import pandas as pd
from pysndfx import AudioEffectsChain
from librosa import load
import shutil

# %%
f = open("D://Background_noise//meta.txt","r")
match_noise_to_type = []
content = f.readlines()

for line in content:
    y = line.split('	')
    audio_filename = y[0][6:len(y[0])]
    audio_category = y[1][0:len(y[1])-1].replace('/', '_')
    
    match_noise_to_type.append((audio_filename, audio_category))

noise_dict = dict(match_noise_to_type)
#print(noise_dict)

# %%
h_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Happy//';
a_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Angry//';
n_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Neutral//';
s_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Sad//';
o_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Other//';

h_test_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Happy_test//'
a_test_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Angry_test//'
n_test_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Neutral_test//'
s_test_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Sad_test//'
o_test_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised_reverberated//Other_test//'

emotion_train_all = [h_directory_all, a_directory_all, n_directory_all, s_directory_all, o_directory_all]
emotion_test_all = [h_test_all, a_test_all, n_test_all, s_test_all, o_test_all]

h_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Happy//';
a_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Angry//';
n_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Neutral//';
s_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Sad//';
o_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Other//';

h_test_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Happy_test//'
a_test_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Angry_test//'
n_test_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Neutral_test//'
s_test_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Sad_test//'
o_test_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Other_test//'

background_noise = 'D://Background_noise//TUT2016//'
background_noise_test = 'D://Background_noise//noise_test//'

background_noise_all = 'D://Background_noise//noise_all//'
background_noise_home = 'D://Background_noise//noise_home//'

emotion_train_home = [h_directory_home, a_directory_home, n_directory_home, s_directory_home, o_directory_home]
emotion_test_home = [h_test_home, a_test_home, n_test_home, s_test_home, o_test_home]

# %%
problematic_neutral = 'D://Datasets//TRAINING//padded//Neutral//'
problematic_sad = 'D://Datasets//TRAINING//padded//Sad//'

# %%
def rename_emotion_wavs(emotion_directory):
    if 'Happy' in emotion_directory:
        word = 'Happy'
    elif 'Angry' in emotion_directory:
        word = 'Angry'
    elif 'Neutral' in emotion_directory:
        word = 'Neutral'
    elif 'Sad' in emotion_directory:
        word = 'Sad'
    else:
        word = 'Other'
    
    index = 0
    for file in os.listdir(emotion_directory):
        src = emotion_directory + file
        dst = emotion_directory + word + str(index) + '.wav'
        try:
            os.rename(src, dst)
        except Exception as e:
            pass
        index += 1
        print(dst)
        
#rename_emotion_wavs(h_directory)
#rename_emotion_wavs(a_directory)
#rename_emotion_wavs(n_directory)
#rename_emotion_wavs(s_directory)
#rename_emotion_wavs(o_directory)

# %%
rename_emotion_wavs(problematic_neutral)
rename_emotion_wavs(problematic_sad)
# Out:
# D://Datasets//TRAINING//padded//Neutral//Neutral0.wav
# D://Datasets//TRAINING//padded//Neutral//Neut
wav
# D://Datasets//TRAINING//padded//Neutral//Neutral733.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral734.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral735.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral736.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral737.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral738.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral739.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral740.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral741.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral742.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral743.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral744.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral745.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral746.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral747.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral748.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral749.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral750.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral751.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral752.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral753.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral754.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral755.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral756.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral757.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral758.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral759.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral760.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral761.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral762.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral763.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral764.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral765.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral766.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral767.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral768.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral769.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral770.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral771.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral772.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral773.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral774.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral775.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral776.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral777.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral778.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral779.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral780.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral781.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral782.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral783.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral784.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral785.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral786.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral787.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral788.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral789.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral790.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral791.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral792.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral793.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral794.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral795.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral796.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral797.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral798.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral799.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral800.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral801.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral802.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral803.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral804.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral805.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral806.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral807.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral808.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral809.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral810.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral811.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral812.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral813.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral814.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral815.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral816.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral817.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral818.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral819.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral820.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral821.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral822.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral823.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral824.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral825.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral826.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral827.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral828.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral829.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral830.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral831.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral832.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral833.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral834.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral835.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral836.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral837.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral838.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral839.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral840.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral841.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral842.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral843.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral844.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral845.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral846.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral847.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral848.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral849.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral850.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral851.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral852.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral853.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral854.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral855.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral856.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral857.wav
# D://Datasets//TRAINING//padded//Neutral//Neutral858.wav
# ...
# D://Datasets//TRAINING//padded//Sad//Sad1467.wav
# D://Datasets//TRAINING//padded//Sad//Sad1468.wav
# D://Datasets//TRAINING//padded//Sad//Sad1469.wav
# D://Datasets//TRAINING//padded//Sad//Sad1470.wav
# D://Datasets//TRAINING//padded//Sad//Sad1471.wav
# D://Datasets//TRAINING//padded//Sad//Sad1472.wav
# D://Datasets//TRAINING//padded//Sad//Sad1473.wav
# D://Datasets//TRAINING//padded//Sad//Sad1474.wav
# D://Datasets//TRAINING//padded//Sad//Sad1475.wav
# D://Datasets//TRAINING//padded//Sad//Sad1476.wav
# D://Datasets//TRAINING//padded//Sad//Sad1477.wav
# D://Datasets//TRAINING//padded//Sad//Sad1478.wav
# D://Datasets//TRAINING//padded//Sad//Sad1479.wav
# D://Datasets//TRAINING//padded//Sad//Sad1480.wav
# D://Datasets//TRAINING//padded//Sad//Sad1481.wav
# D://Datasets//TRAINING//padded//Sad//Sad1482.wav
# D://Datasets//TRAINING//padded//Sad//Sad1483.wav
# D://Datasets//TRAINING//padded//Sad//Sad1484.wav
# D://Datasets//TRAINING//padded//Sad//Sad1485.wav
# D://Datasets//TRAINING//padded//Sad//Sad1486.wav
# D://Datasets//TRAINING//padded//Sad//Sad1487.wav
# D://Datasets//TRAINING//padded//Sad//Sad1488.wav
# D://Datasets//TRAINING//padded//Sad//Sad1489.wav
# D://Datasets//TRAINING//padded//Sad//Sad1490.wav
# D://Datasets//TRAINING//padded//Sad//Sad1491.wav
# D://Datasets//TRAINING//padded//Sad//Sad1492.wav
# D://Datasets//TRAINING//padded//Sad//Sad1493.wav
# D://Datasets//TRAINING//padded//Sad//Sad1494.wav
# D://Datasets//TRAINING//padded//Sad//Sad1495.wav
# D://Datasets//TRAINING//padded//Sad//Sad1496.wav
# D://Datasets//TRAINING//padded//Sad//Sad1497.wav
# D://Datasets//TRAINING//padded//Sad//Sad1498.wav
# D://Datasets//TRAINING//padded//Sad//Sad1499.wav
# D://Datasets//TRAINING//padded//Sad//Sad1500.wav
# D://Datasets//TRAINING//padded//Sad//Sad1501.wav
# D://Datasets//TRAINING//padded//Sad//Sad1502.wav
# D://Datasets//TRAINING//padded//Sad//Sad1503.wav
# D://Datasets//TRAINING//padded//Sad//Sad1504.wav
# D://Datasets//TRAINING//padded//Sad//Sad1505.wav
# D://Datasets//TRAINING//padded//Sad//Sad1506.wav
# D://Datasets//TRAINING//padded//Sad//Sad1507.wav
# D://Datasets//TRAINING//padded//Sad//Sad1508.wav
# D://Datasets//TRAINING//padded//Sad//Sad1509.wav
# D://Datasets//TRAINING//padded//Sad//Sad1510.wav
# D://Datasets//TRAINING//padded//Sad//Sad1511.wav
# D://Datasets//TRAINING//padded//Sad//Sad1512.wav
# D://Datasets//TRAINING//padded//Sad//Sad1513.wav
# D://Datasets//TRAINING//padded//Sad//Sad1514.wav
# D://Datasets//TRAINING//padded//Sad//Sad1515.wav
# D://Datasets//TRAINING//padded//Sad//Sad1516.wav
# D://Datasets//TRAINING//padded//Sad//Sad1517.wav
# D://Datasets//TRAINING//padded//Sad//Sad1518.wav
# D://Datasets//TRAINING//padded//Sad//Sad1519.wav
# D://Datasets//TRAINING//padded//Sad//Sad1520.wav
# D://Datasets//TRAINING//padded//Sad//Sad1521.wav
# D://Datasets//TRAINING//padded//Sad//Sad1522.wav
# D://Datasets//TRAINING//padded//Sad//Sad1523.wav
# D://Datasets//TRAINING//padded//Sad//Sad1524.wav
# D://Datasets//TRAINING//padded//Sad//Sad1525.wav
# D://Datasets//TRAINING//padded//Sad//Sad1526.wav
# D://Datasets//TRAINING//padded//Sad//Sad1527.wav
# D://Datasets//TRAINING//padded//Sad//Sad1528.wav
# D://Datasets//TRAINING//padded//Sad//Sad1529.wav
# D://Datasets//TRAINING//padded//Sad//Sad1530.wav
# D://Datasets//TRAINING//padded//Sad//Sad1531.wav
# D://Datasets//TRAINING//padded//Sad//Sad1532.wav
# D://Datasets//TRAINING//padded//Sad//Sad1533.wav
# D://Datasets//TRAINING//padded//Sad//Sad1534.wav
# D://Datasets//TRAINING//padded//Sad//Sad1535.wav
# D://Datasets//TRAINING//padded//Sad//Sad1536.wav
# D://Datasets//TRAINING//padded//Sad//Sad1537.wav
# D://Datasets//TRAINING//padded//Sad//Sad1538.wav
# D://Datasets//TRAINING//padded//Sad//Sad1539.wav
# D://Datasets//TRAINING//padded//Sad//Sad1540.wav
# D://Datasets//TRAINING//padded//Sad//Sad1541.wav
# D://Datasets//TRAINING//padded//Sad//Sad1542.wav
# D://Datasets//TRAINING//padded//Sad//Sad1543.wav
# D://Datasets//TRAINING//padded//Sad//Sad1544.wav
# D://Datasets//TRAINING//padded//Sad//Sad1545.wav
# D://Datasets//TRAINING//padded//Sad//Sad1546.wav
# D://Datasets//TRAINING//padded//Sad//Sad1547.wav
# D://Datasets//TRAINING//padded//Sad//Sad1548.wav
# D://Datasets//TRAINING//padded//Sad//Sad1549.wav
# D://Datasets//TRAINING//padded//Sad//Sad1550.wav
# D://Datasets//TRAINING//padded//Sad//Sad1551.wav
# D://Datasets//TRAINING//padded//Sad//Sad1552.wav
# D://Datasets//TRAINING//padded//Sad//Sad1553.wav
# D://Datasets//TRAINING//padded//Sad//Sad1554.wav
# D://Datasets//TRAINING//padded//Sad//Sad1555.wav
# D://Datasets//TRAINING//padded//Sad//Sad1556.wav
# D://Datasets//TRAINING//padded//Sad//Sad1557.wav
# D://Datasets//TRAINING//padded//Sad//Sad1558.wav
# D://Datasets//TRAINING//padded//Sad//Sad1559.wav
# D://Datasets//TRAINING//padded//Sad//Sad1560.wav
# D://Datasets//TRAINING//padded//Sad//Sad1561.wav
# D://Datasets//TRAINING//padded//Sad//Sad1562.wav
# D://Datasets//TRAINING//padded//Sad//Sad1563.wav
# D://Datasets//TRAINING//padded//Sad//Sad1564.wav
# D://Datasets//TRAINING//padded//Sad//Sad1565.wav
# D://Datasets//TRAINING//padded//Sad//Sad1566.wav
# D://Datasets//TRAINING//padded//Sad//Sad1567.wav
# D://Datasets//TRAINING//padded//Sad//Sad1568.wav
# D://Datasets//TRAINING//padded//Sad//Sad1569.wav
# D://Datasets//TRAINING//padded//Sad//Sad1570.wav
# D://Datasets//TRAINING//padded//Sad//Sad1571.wav
# D://Datasets//TRAINING//padded//Sad//Sad1572.wav
# D://Datasets//TRAINING//padded//Sad//Sad1573.wav
# D://Datasets//TRAINING//padded//Sad//Sad1574.wav
# D://Datasets//TRAINING//padded//Sad//Sad1575.wav
# D://Datasets//TRAINING//padded//Sad//Sad1576.wav
# D://Datasets//TRAINING//padded//Sad//Sad1577.wav
# D://Datasets//TRAINING//padded//Sad//Sad1578.wav
# D://Datasets//TRAINING//padded//Sad//Sad1579.wav
# D://Datasets//TRAINING//padded//Sad//Sad1580.wav
# D://Datasets//TRAINING//padded//Sad//Sad1581.wav
# D://Datasets//TRAINING//padded//Sad//Sad1582.wav
# D://Datasets//TRAINING//padded//Sad//Sad1583.wav
# D://Datasets//TRAINING//padded//Sad//Sad1584.wav
# D://Datasets//TRAINING//padded//Sad//Sad1585.wav
# D://Datasets//TRAINING//padded//Sad//Sad1586.wav
# D://Datasets//TRAINING//padded//Sad//Sad1587.wav
# D://Datasets//TRAINING//padded//Sad//Sad1588.wav
# D://Datasets//TRAINING//padded//Sad//Sad1589.wav
# D://Datasets//TRAINING//padded//Sad//Sad1590.wav
# D://Datasets//TRAINING//padded//Sad//Sad1591.wav
# D://Datasets//TRAINING//padded//Sad//Sad1592.wav
# D://Datasets//TRAINING//padded//Sad//Sad1593.wav
# D://Datasets//TRAINING//padded//Sad//Sad1594.wav
# D://Datasets//TRAINING//padded//Sad//Sad1595.wav
# D://Datasets//TRAINING//padded//Sad//Sad1596.wav
# D://Datasets//TRAINING//padded//Sad//Sad1597.wav
# D://Datasets//TRAINING//padded//Sad//Sad1598.wav
# D://Datasets//TRAINING//padded//Sad//Sad1599.wav
# D://Datasets//TRAINING//padded//Sad//Sad1600.wav
# D://Datasets//TRAINING//padded//Sad//Sad1601.wav
# D://Datasets//TRAINING//padded//Sad//Sad1602.wav
# D://Datasets//TRAINING//padded//Sad//Sad1603.wav
# D://Datasets//TRAINING//padded//Sad//Sad1604.wav
# D://Datasets//TRAINING//padded//Sad//Sad1605.wav
# D://Datasets//TRAINING//padded//Sad//Sad1606.wav
# D://Datasets//TRAINING//padded//Sad//Sad1607.wav
# D://Datasets//TRAINING//padded//Sad//Sad1608.wav
# D://Datasets//TRAINING//padded//Sad//Sad1609.wav
# D://Datasets//TRAINING//padded//Sad//Sad1610.wav
# D://Datasets//TRAINING//padded//Sad//Sad1611.wav
# D://Datasets//TRAINING//padded//Sad//Sad1612.wav
# D://Datasets//TRAINING//padded//Sad//Sad1613.wav
# D://Datasets//TRAINING//padded//Sad//Sad1614.wav
# D://Datasets//TRAINING//padded//Sad//Sad1615.wav
# D://Datasets//TRAINING//padded//Sad//Sad1616.wav
# D://Datasets//TRAINING//padded//Sad//Sad1617.wav
# D://Datasets//TRAINING//padded//Sad//Sad1618.wav
# D://Datasets//TRAINING//padded//Sad//Sad1619.wav
# D://Datasets//TRAINING//padded//Sad//Sad1620.wav
# D://Datasets//TRAINING//padded//Sad//Sad1621.wav
# D://Datasets//TRAINING//padded//Sad//Sad1622.wav
# D://Datasets//TRAINING//padded//Sad//Sad1623.wav
# D://Datasets//TRAINING//padded//Sad//Sad1624.wav
# D://Datasets//TRAINING//padded//Sad//Sad1625.wav
# D://Datasets//TRAINING//padded//Sad//Sad1626.wav
# D://Datasets//TRAINING//padded//Sad//Sad1627.wav
# D://Datasets//TRAINING//padded//Sad//Sad1628.wav
# D://Datasets//TRAINING//padded//Sad//Sad1629.wav
# D://Datasets//TRAINING//padded//Sad//Sad1630.wav
# D://Datasets//TRAINING//padded//Sad//Sad1631.wav
# D://Datasets//TRAINING//padded//Sad//Sad1632.wav
# D://Datasets//TRAINING//padded//Sad//Sad1633.wav
# D://Datasets//TRAINING//padded//Sad//Sad1634.wav
# D://Datasets//TRAINING//padded//Sad//Sad1635.wav
# D://Datasets//TRAINING//padded//Sad//Sad1636.wav
# D://Datasets//TRAINING//padded//Sad//Sad1637.wav
# D://Datasets//TRAINING//padded//Sad//Sad1638.wav
# D://Datasets//TRAINING//padded//Sad//Sad1639.wav
# D://Datasets//TRAINING//padded//Sad//Sad1640.wav
# D://Datasets//TRAINING//padded//Sad//Sad1641.wav
# D://Datasets//TRAINING//padded//Sad//Sad1642.wav
# D://Datasets//TRAINING//padded//Sad//Sad1643.wav
# D://Datasets//TRAINING//padded//Sad//Sad1644.wav
# D://Datasets//TRAINING//padded//Sad//Sad1645.wav
# D://Datasets//TRAINING//padded//Sad//Sad1646.wav
# D://Datasets//TRAINING//padded//Sad//Sad1647.wav
# D://Datasets//TRAINING//padded//Sad//Sad1648.wav
# D://Datasets//TRAINING//padded//Sad//Sad1649.wav
# D://Datasets//TRAINING//padded//Sad//Sad1650.wav
# D://Datasets//TRAINING//padded//Sad//Sad1651.wav
# D://Datasets//TRAINING//padded//Sad//Sad1652.wav
# D://Datasets//TRAINING//padded//Sad//Sad1653.wav
# D://Datasets//TRAINING//padded//Sad//Sad1654.wav
# D://Datasets//TRAINING//padded//Sad//Sad1655.wav
# D://Datasets//TRAINING//padded//Sad//Sad1656.wav
# D://Datasets//TRAINING//padded//Sad//Sad1657.wav
# D://Datasets//TRAINING//padded//Sad//Sad1658.wav
# D://Datasets//TRAINING//padded//Sad//Sad1659.wav
# D://Datasets//TRAINING//padded//Sad//Sad1660.wav
# D://Datasets//TRAINING//padded//Sad//Sad1661.wav
# D://Datasets//TRAINING//padded//Sad//Sad1662.wav
# D://Datasets//TRAINING//padded//Sad//Sad1663.wav
# D://Datasets//TRAINING//padded//Sad//Sad1664.wav
# D://Datasets//TRAINING//padded//Sad//Sad1665.wav
# D://Datasets//TRAINING//padded//Sad//Sad1666.wav
# D://Datasets//TRAINING//padded//Sad//Sad1667.wav
# D://Datasets//TRAINING//padded//Sad//Sad1668.wav
# D://Datasets//TRAINING//padded//Sad//Sad1669.wav
# D://Datasets//TRAINING//padded//Sad//Sad1670.wav
# D://Datasets//TRAINING//padded//Sad//Sad1671.wav
# D://Datasets//TRAINING//padded//Sad//Sad1672.wav
# D://Datasets//TRAINING//padded//Sad//Sad1673.wav
# D://Datasets//TRAINING//padded//Sad//Sad1674.wav
# D://Datasets//TRAINING//padded//Sad//Sad1675.wav
# D://Datasets//TRAINING//padded//Sad//Sad1676.wav
# D://Datasets//TRAINING//padded//Sad//Sad1677.wav
# D://Datasets//TRAINING//padded//Sad//Sad1678.wav
# D://Datasets//TRAINING//padded//Sad//Sad1679.wav
# D://Datasets//TRAINING//padded//Sad//Sad1680.wav
# D://Datasets//TRAINING//padded//Sad//Sad1681.wav
# D://Datasets//TRAINING//padded//Sad//Sad1682.wav
# D://Datasets//TRAINING//padded//Sad//Sad1683.wav
# D://Datasets//TRAINING//padded//Sad//Sad1684.wav
# D://Datasets//TRAINING//padded//Sad//Sad1685.wav
# D://Datasets//TRAINING//padded//Sad//Sad1686.wav
# D://Datasets//TRAINING//padded//Sad//Sad1687.wav
# D://Datasets//TRAINING//padded//Sad//Sad1688.wav
# D://Datasets//TRAINING//padded//Sad//Sad1689.wav
# D://Datasets//TRAINING//padded//Sad//Sad1690.wav
# D://Datasets//TRAINING//padded//Sad//Sad1691.wav
# D://Datasets//TRAINING//padded//Sad//Sad1692.wav
# D://Datasets//TRAINING//padded//Sad//Sad1693.wav
# D://Datasets//TRAINING//padded//Sad//Sad1694.wav
# D://Datasets//TRAINING//padded//Sad//Sad1695.wav
# D://Datasets//TRAINING//padded//Sad//Sad1696.wav
# D://Datasets//TRAINING//padded//Sad//Sad1697.wav
# D://Datasets//TRAINING//padded//Sad//Sad1698.wav
# D://Datasets//TRAINING//padded//Sad//Sad1699.wav
# D://Datasets//TRAINING//padded//Sad//Sad1700.wav
# D://Datasets//TRAINING//padded//Sad//Sad1701.wav
# D://Datasets//TRAINING//padded//Sad//Sad1702.wav
# D://Datasets//TRAINING//padded//Sad//Sad1703.wav
# D://Datasets//TRAINING//padded//Sad//Sad1704.wav
# D://Datasets//TRAINING//padded//Sad//Sad1705.wav
# D://Datasets//TRAINING//padded//Sad//Sad1706.wav
# D://Datasets//TRAINING//padded//Sad//Sad1707.wav
# D://Datasets//TRAINING//padded//Sad//Sad1708.wav
# D://Datasets//TRAINING//padded//Sad//Sad1709.wav
# D://Datasets//TRAINING//padded//Sad//Sad1710.wav
# D://Datasets//TRAINING//padded//Sad//Sad1711.wav
# D://Datasets//TRAINING//padded//Sad//Sad1712.wav
# D://Datasets//TRAINING//padded//Sad//Sad1713.wav
# D://Datasets//TRAINING//padded//Sad//Sad1714.wav
# D://Datasets//TRAINING//padded//Sad//Sad1715.wav
# D://Datasets//TRAINING//padded//Sad//Sad1716.wav
# D://Datasets//TRAINING//padded//Sad//Sad1717.wav
# D://Datasets//TRAINING//padded//Sad//Sad1718.wav
# D://Datasets//TRAINING//padded//Sad//Sad1719.wav
# D://Datasets//TRAINING//padded//Sad//Sad1720.wav
# D://Datasets//TRAINING//padded//Sad//Sad1721.wav
# D://Datasets//TRAINING//padded//Sad//Sad1722.wav
# D://Datasets//TRAINING//padded//Sad//Sad1723.wav
# D://Datasets//TRAINING//padded//Sad//Sad1724.wav
# D://Datasets//TRAINING//padded//Sad//Sad1725.wav
# D://Datasets//TRAINING//padded//Sad//Sad1726.wav
# D://Datasets//TRAINING//padded//Sad//Sad1727.wav
# D://Datasets//TRAINING//padded//Sad//Sad1728.wav
# D://Datasets//TRAINING//padded//Sad//Sad1729.wav
# D://Datasets//TRAINING//padded//Sad//Sad1730.wav
# D://Datasets//TRAINING//padded//Sad//Sad1731.wav
# D://Datasets//TRAINING//padded//Sad//Sad1732.wav
# D://Datasets//TRAINING//padded//Sad//Sad1733.wav
# D://Datasets//TRAINING//padded//Sad//Sad1734.wav
# D://Datasets//TRAINING//padded//Sad//Sad1735.wav
# D://Datasets//TRAINING//padded//Sad//Sad1736.wav
# D://Datasets//TRAINING//padded//Sad//Sad1737.wav
# D://Datasets//TRAINING//padded//Sad//Sad1738.wav
# D://Datasets//TRAINING//padded//Sad//Sad1739.wav
# D://Datasets//TRAINING//padded//Sad//Sad1740.wav
# D://Datasets//TRAINING//padded//Sad//Sad1741.wav
# D://Datasets//TRAINING//padded//Sad//Sad1742.wav
# D://Datasets//TRAINING//padded//Sad//Sad1743.wav
# D://Datasets//TRAINING//padded//Sad//Sad1744.wav
# D://Datasets//TRAINING//padded//Sad//Sad1745.wav
# D://Datasets//TRAINING//padded//Sad//Sad1746.wav
# D://Datasets//TRAINING//padded//Sad//Sad1747.wav
# D://Datasets//TRAINING//padded//Sad//Sad1748.wav
# D://Datasets//TRAINING//padded//Sad//Sad1749.wav
# D://Datasets//TRAINING//padded//Sad//Sad1750.wav
# D://Datasets//TRAINING//padded//Sad//Sad1751.wav
# D://Datasets//TRAINING//padded//Sad//Sad1752.wav
# D://Datasets//TRAINING//padded//Sad//Sad1753.wav
# D://Datasets//TRAINING//padded//Sad//Sad1754.wav
# D://Datasets//TRAINING//padded//Sad//Sad1755.wav
# D://Datasets//TRAINING//padded//Sad//Sad1756.wav
# D://Datasets//TRAINING//padded//Sad//Sad1757.wav
# D://Datasets//TRAINING//padded//Sad//Sad1758.wav
# D://Datasets//TRAINING//padded//Sad//Sad1759.wav
# D://Datasets//TRAINING//padded//Sad//Sad1760.wav
# D://Datasets//TRAINING//padded//Sad//Sad1761.wav
# D://Datasets//TRAINING//padded//Sad//Sad1762.wav
# D://Datasets//TRAINING//padded//Sad//Sad1763.wav
# D://Datasets//TRAINING//padded//Sad//Sad1764.wav
# D://Datasets//TRAINING//padded//Sad//Sad1765.wav
# D://Datasets//TRAINING//padded//Sad//Sad1766.wav
# D://Datasets//TRAINING//padded//Sad//Sad1767.wav
# D://Datasets//TRAINING//padded//Sad//Sad1768.wav
# D://Datasets//TRAINING//padded//Sad//Sad1769.wav
# D://Datasets//TRAINING//padded//Sad//Sad1770.wav
# D://Datasets//TRAINING//padded//Sad//Sad1771.wav
# D://Datasets//TRAINING//padded//Sad//Sad1772.wav
# D://Datasets//TRAINING//padded//Sad//Sad1773.wav
# D://Datasets//TRAINING//padded//Sad//Sad1774.wav
# D://Datasets//TRAINING//padded//Sad//Sad1775.wav
# D://Datasets//TRAINING//padded//Sad//Sad1776.wav
# D://Datasets//TRAINING//padded//Sad//Sad1777.wav
# D://Datasets//TRAINING//padded//Sad//Sad1778.wav
# D://Datasets//TRAINING//padded//Sad//Sad1779.wav
# D://Datasets//TRAINING//padded//Sad//Sad1780.wav
# D://Datasets//TRAINING//padded//Sad//Sad1781.wav
# D://Datasets//TRAINING//padded//Sad//Sad1782.wav
# D://Datasets//TRAINING//padded//Sad//Sad1783.wav
# D://Datasets//TRAINING//padded//Sad//Sad1784.wav
# D://Datasets//TRAINING//padded//Sad//Sad1785.wav
# D://Datasets//TRAINING//padded//Sad//Sad1786.wav
# D://Datasets//TRAINING//padded//Sad//Sad1787.wav
# D://Datasets//TRAINING//padded//Sad//Sad1788.wav
# D://Datasets//TRAINING//padded//Sad//Sad1789.wav
# D://Datasets//TRAINING//padded//Sad//Sad1790.wav
# D://Datasets//TRAINING//padded//Sad//Sad1791.wav
# D://Datasets//TRAINING//padded//Sad//Sad1792.wav

# %%
def rename_noise_wavs(noise_directory):
    index = 0
    for noise in os.listdir(noise_directory):
        noise_type = noise_dict.get(noise)
        new_noise_name = noise_type + '_' + str(index)
        src = noise_directory + noise
        dst = noise_directory + new_noise_name + '.wav'
        os.rename(src, dst) 
        index += 1

        print(dst)

#rename_noise_wavs(background_noise_all)

# %%
def delete_directory(path):
    shutil.rmtree(path, ignore_errors=True)

# %%
def partition_directory(path, new_path, percent):
    
    if not os.path.exists(new_path):
        os.mkdir(new_path)
    else:
        delete_directory(new_path)
        os.makdir(new_path)
        
    total = len(os.listdir(path))
    test_number = int(total * percent)
    test_set = np.random.permutation(total)[0:test_number]
    
    for index in test_set:
        try:
            if os.listdir(path)[index].endswith('.wav'):
                original_location = path + os.listdir(path)[index]
                new_location = new_path + os.listdir(path)[index]
                os.rename(original_location, new_location)
                print(new_location)
        except:
            pass

    
    print('# of training data + # of testing data = ' + str(total))
    print(str(percent) + ' of the data is in training set')
# D://Datasets//TRAINING//padded//Sad//Sad1490.wav
# D://Datasets//TRAINING//padded//Sad//Sad1491.wav
# D://Datasets//TRAINING//padded//Sad//Sad1492.wav
# D://Datasets//TRAINING//padded//Sad//Sad1493.wav
# D://Datasets//TRAINING//padded//Sad//Sad1494.wav
# D://Datasets//TRAINING//padded//Sad//Sad1495.wav
# D://Datasets//TRAINING//padded//Sad//Sad1496.wav
# D://Datasets//TRAINING//padded//Sad//Sad1497.wav
# D://Datasets//TRAINING//padded//Sad//Sad1498.wav
# D://Datasets//TRAINING//padded//Sad//Sad1499.wav
# D://Datasets//TRAINING//padded//Sad//Sad1500.wav
# D://Datasets//TRAINING//padded//Sad//Sad1501.wav
# D://Datasets//TRAINING//padded//Sad//Sad1502.wav
# D://Datasets//TRAINING//padded//Sad//Sad1503.wav
# D://Datasets//TRAINING//padded//Sad//Sad1504.wav
# D://Datasets//TRAINING//padded//Sad//Sad1505.wav
# D://Datasets//TRAINING//padded//Sad//Sad1506.wav
# D://Datasets//TRAINING//padded//Sad//Sad1507.wav
# D://Datasets//TRAINING//padded//Sad//Sad1508.wav
# D://Datasets//TRAINING//padded//Sad//Sad1509.wav
# D://Datasets//TRAINING//padded//Sad//Sad1510.wav
# D://Datasets//TRAINING//padded//Sad//Sad1511.wav
# D://Datasets//TRAINING//padded//Sad//Sad1512.wav
# D://Datasets//TRAINING//padded//Sad//Sad1513.wav
# D://Datasets//TRAINING//padded//Sad//Sad1514.wav
# D://Datasets//TRAINING//padded//Sad//Sad1515.wav
# D://Datasets//TRAINING//padded//Sad//Sad1516.wav
# D://Datasets//TRAINING//padded//Sad//Sad1517.wav
# D://Datasets//TRAINING//padded//Sad//Sad1518.wav
# D://Datasets//TRAINING//padded//Sad//Sad1519.wav
# D://Datasets//TRAINING//padded//Sad//Sad1520.wav
# D://Datasets//TRAINING//padded//Sad//Sad1521.wav
# D://Datasets//TRAINING//padded//Sad//Sad1522.wav
# D://Datasets//TRAINING//padded//Sad//Sad1523.wav
# D://Datasets//TRAINING//padded//Sad//Sad1524.wav
# D://Datasets//TRAINING//padded//Sad//Sad1525.wav
# D://Datasets//TRAINING//padded//Sad//Sad1526.wav
# D://Datasets//TRAINING//padded//Sad//Sad1527.wav
# D://Datasets//TRAINING//padded//Sad//Sad1528.wav
# D://Datasets//TRAINING//padded//Sad//Sad1529.wav
# D://Datasets//TRAINING//padded//Sad//Sad1530.wav
# D://Datasets//TRAINING//padded//Sad//Sad1531.wav
# D://Datasets//TRAINING//padded//Sad//Sad1532.wav
# D://Datasets//TRAINING//padded//Sad//Sad1533.wav
# D://Datasets//TRAINING//padded//Sad//Sad1534.wav
# D://Datasets//TRAINING//padded//Sad//Sad1535.wav
# D://Datasets//TRAINING//padded//Sad//Sad1536.wav
# D://Datasets//TRAINING//padded//Sad//Sad1537.wav
# D://Datasets//TRAINING//padded//Sad//Sad1538.wav
# D://Datasets//TRAINING//padded//Sad//Sad1539.wav
# D://Datasets//TRAINING//padded//Sad//Sad1540.wav
# D://Datasets//TRAINING//padded//Sad//Sad1541.wav
# D://Datasets//TRAINING//padded//Sad//Sad1542.wav
# D://Datasets//TRAINING//padded//Sad//Sad1543.wav
# D://Datasets//TRAINING//padded//Sad//Sad1544.wav
# D://Datasets//TRAINING//padded//Sad//Sad1545.wav
# D://Datasets//TRAINING//padded//Sad//Sad1546.wav
# D://Datasets//TRAINING//padded//Sad//Sad1547.wav
# D://Datasets//TRAINING//padded//Sad//Sad1548.wav
# D://Datasets//TRAINING//padded//Sad//Sad1549.wav
# D://Datasets//TRAINING//padded//Sad//Sad1550.wav
# D://Datasets//TRAINING//padded//Sad//Sad1551.wav
# D://Datasets//TRAINING//padded//Sad//Sad1552.wav
# D://Datasets//TRAINING//padded//Sad//Sad1553.wav
# D://Datasets//TRAINING//padded//Sad//Sad1554.wav
# D://Datasets//TRAINING//padded//Sad//Sad1555.wav
# D://Datasets//TRAINING//padded//Sad//Sad1556.wav
# D://Datasets//TRAINING//padded//Sad//Sad1557.wav
# D://Datasets//TRAINING//padded//Sad//Sad1558.wav
# D://Datasets//TRAINING//padded//Sad//Sad1559.wav
# D://Datasets//TRAINING//padded//Sad//Sad1560.wav
# D://Datasets//TRAINING//padded//Sad//Sad1561.wav
# D://Datasets//TRAINING//padded//Sad//Sad1562.wav
# D://Datasets//TRAINING//padded//Sad//Sad1563.wav
# D://Datasets//TRAINING//padded//Sad//Sad1564.wav
# D://Datasets//TRAINING//padded//Sad//Sad1565.wav
# D://Datasets//TRAINING//padded//Sad//Sad1566.wav
# D://Datasets//TRAINING//padded//Sad//Sad1567.wav
# D://Datasets//TRAINING//padded//Sad//Sad1568.wav
# D://Datasets//TRAINING//padded//Sad//Sad1569.wav
# D://Datasets//TRAINING//padded//Sad//Sad1570.wav
# D://Datasets//TRAINING//padded//Sad//Sad1571.wav
# D://Datasets//TRAINING//padded//Sad//Sad1572.wav
# D://Datasets//TRAINING//padded//Sad//Sad1573.wav
# D://Datasets//TRAINING//padded//Sad//Sad1574.wav
# D://Datasets//TRAINING//padded//Sad//Sad1575.wav
# D://Datasets//TRAINING//padded//Sad//Sad1576.wav
# D://Datasets//TRAINING//padded//Sad//Sad1577.wav
# D://Datasets//TRAINING//padded//Sad//Sad1578.wav
# D://Datasets//TRAINING//padded//Sad//Sad1579.wav
# D://Datasets//TRAINING//padded//Sad//Sad1580.wav
# D://Datasets//TRAINING//padded//Sad//Sad1581.wav
# D://Datasets//TRAINING//padded//Sad//Sad1582.wav
# D://Datasets//TRAINING//padded//Sad//Sad1583.wav
# D://Datasets//TRAINING//padded//Sad//Sad1584.wav
# D://Datasets//TRAINING//padded//Sad//Sad1585.wav
# D://Datasets//TRAINING//padded//Sad//Sad1586.wav
# D://Datasets//TRAINING//padded//Sad//Sad1587.wav
# D://Datasets//TRAINING//padded//Sad//Sad1588.wav
# D://Datasets//TRAINING//padded//Sad//Sad1589.wav
# D://Datasets//TRAINING//padded//Sad//Sad1590.wav
# D://Datasets//TRAINING//padded//Sad//Sad1591.wav
# D://Datasets//TRAINING//padded//Sad//Sad1592.wav
# D://Datasets//TRAINING//padded//Sad//Sad1593.wav
# D://Datasets//TRAINING//padded//Sad//Sad1594.wav
# D://Datasets//TRAINING//padded//Sad//Sad1595.wav
# D://Datasets//TRAINING//padded//Sad//Sad1596.wav
# D://Datasets//TRAINING//padded//Sad//Sad1597.wav
# D://Datasets//TRAINING//padded//Sad//Sad1598.wav
# D://Datasets//TRAINING//padded//Sad//Sad1599.wav
# D://Datasets//TRAINING//padded//Sad//Sad1600.wav
# D://Datasets//TRAINING//padded//Sad//Sad1601.wav
# D://Datasets//TRAINING//padded//Sad//Sad1602.wav
# D://Datasets//TRAINING//padded//Sad//Sad1603.wav
# D://Datasets//TRAINING//padded//Sad//Sad1604.wav
# D://Datasets//TRAINING//padded//Sad//Sad1605.wav
# D://Datasets//TRAINING//padded//Sad//Sad1606.wav
# D://Datasets//TRAINING//padded//Sad//Sad1607.wav
# D://Datasets//TRAINING//padded//Sad//Sad1608.wav
# D://Datasets//TRAINING//padded//Sad//Sad1609.wav
# D://Datasets//TRAINING//padded//Sad//Sad1610.wav
# D://Datasets//TRAINING//padded//Sad//Sad1611.wav
# D://Datasets//TRAINING//padded//Sad//Sad1612.wav
# D://Datasets//TRAINING//padded//Sad//Sad1613.wav
# D://Datasets//TRAINING//padded//Sad//Sad1614.wav
# D://Datasets//TRAINING//padded//Sad//Sad1615.wav
# D://Datasets//TRAINING//padded//Sad//Sad1616.wav
# D://Datasets//TRAINING//padded//Sad//Sad1617.wav
# D://Datasets//TRAINING//padded//Sad//Sad1618.wav
# D://Datasets//TRAINING//padded//Sad//Sad1619.wav
# D://Datasets//TRAINING//padded//Sad//Sad1620.wav
# D://Datasets//TRAINING//padded//Sad//Sad1621.wav
# D://Datasets//TRAINING//padded//Sad//Sad1622.wav
# D://Datasets//TRAINING//padded//Sad//Sad1623.wav
# D://Datasets//TRAINING//padded//Sad//Sad1624.wav
# D://Datasets//TRAINING//padded//Sad//Sad1625.wav
# D://Datasets//TRAINING//padded//Sad//Sad1626.wav
# D://Datasets//TRAINING//padded//Sad//Sad1627.wav
# D://Datasets//TRAINING//padded//Sad//Sad1628.wav
# D://Datasets//TRAINING//padded//Sad//Sad1629.wav
# D://Datasets//TRAINING//padded//Sad//Sad1630.wav
# D://Datasets//TRAINING//padded//Sad//Sad1631.wav
# D://Datasets//TRAINING//padded//Sad//Sad1632.wav
# D://Datasets//TRAINING//padded//Sad//Sad1633.wav
# D://Datasets//TRAINING//padded//Sad//Sad1634.wav
# D://Datasets//TRAINING//padded//Sad//Sad1635.wav
# D://Datasets//TRAINING//padded//Sad//Sad1636.wav
# D://Datasets//TRAINING//padded//Sad//Sad1637.wav
# D://Datasets//TRAINING//padded//Sad//Sad1638.wav
# D://Datasets//TRAINING//padded//Sad//Sad1639.wav
# D://Datasets//TRAINING//padded//Sad//Sad1640.wav
# D://Datasets//TRAINING//padded//Sad//Sad1641.wav
# D://Datasets//TRAINING//padded//Sad//Sad1642.wav
# D://Datasets//TRAINING//padded//Sad//Sad1643.wav
# D://Datasets//TRAINING//padded//Sad//Sad1644.wav
# D://Datasets//TRAINING//padded//Sad//Sad1645.wav
# D://Datasets//TRAINING//padded//Sad//Sad1646.wav
# D://Datasets//TRAINING//padded//Sad//Sad1647.wav
# D://Datasets//TRAINING//padded//Sad//Sad1648.wav
# D://Datasets//TRAINING//padded//Sad//Sad1649.wav
# D://Datasets//TRAINING//padded//Sad//Sad1650.wav
# D://Datasets//TRAINING//padded//Sad//Sad1651.wav
# D://Datasets//TRAINING//padded//Sad//Sad1652.wav
# D://Datasets//TRAINING//padded//Sad//Sad1653.wav
# D://Datasets//TRAINING//padded//Sad//Sad1654.wav
# D://Datasets//TRAINING//padded//Sad//Sad1655.wav
# D://Datasets//TRAINING//padded//Sad//Sad1656.wav
# D://Datasets//TRAINING//padded//Sad//Sad1657.wav
# D://Datasets//TRAINING//padded//Sad//Sad1658.wav
# D://Datasets//TRAINING//padded//Sad//Sad1659.wav
# D://Datasets//TRAINING//padded//Sad//Sad1660.wav
# D://Datasets//TRAINING//padded//Sad//Sad1661.wav
# D://Datasets//TRAINING//padded//Sad//Sad1662.wav
# D://Datasets//TRAINING//padded//Sad//Sad1663.wav
# D://Datasets//TRAINING//padded//Sad//Sad1664.wav
# D://Datasets//TRAINING//padded//Sad//Sad1665.wav
# D://Datasets//TRAINING//padded//Sad//Sad1666.wav
# D://Datasets//TRAINING//padded//Sad//Sad1667.wav
# D://Datasets//TRAINING//padded//Sad//Sad1668.wav
# D://Datasets//TRAINING//padded//Sad//Sad1669.wav
# D://Datasets//TRAINING//padded//Sad//Sad1670.wav
# D://Datasets//TRAINING//padded//Sad//Sad1671.wav
# D://Datasets//TRAINING//padded//Sad//Sad1672.wav
# D://Datasets//TRAINING//padded//Sad//Sad1673.wav
# D://Datasets//TRAINING//padded//Sad//Sad1674.wav
# D://Datasets//TRAINING//padded//Sad//Sad1675.wav
# D://Datasets//TRAINING//padded//Sad//Sad1676.wav
# D://Datasets//TRAINING//padded//Sad//Sad1677.wav
# D://Datasets//TRAINING//padded//Sad//Sad1678.wav
# D://Datasets//TRAINING//padded//Sad//Sad1679.wav
# D://Datasets//TRAINING//padded//Sad//Sad1680.wav
# D://Datasets//TRAINING//padded//Sad//Sad1681.wav
# D://Datasets//TRAINING//padded//Sad//Sad1682.wav
# D://Datasets//TRAINING//padded//Sad//Sad1683.wav
# D://Datasets//TRAINING//padded//Sad//Sad1684.wav
# D://Datasets//TRAINING//padded//Sad//Sad1685.wav
# D://Datasets//TRAINING//padded//Sad//Sad1686.wav
# D://Datasets//TRAINING//padded//Sad//Sad1687.wav
# D://Datasets//TRAINING//padded//Sad//Sad1688.wav
# D://Datasets//TRAINING//padded//Sad//Sad1689.wav
# D://Datasets//TRAINING//padded//Sad//Sad1690.wav
# D://Datasets//TRAINING//padded//Sad//Sad1691.wav
# D://Datasets//TRAINING//padded//Sad//Sad1692.wav
# D://Datasets//TRAINING//padded//Sad//Sad1693.wav
# D://Datasets//TRAINING//padded//Sad//Sad1694.wav
# D://Datasets//TRAINING//padded//Sad//Sad1695.wav
# D://Datasets//TRAINING//padded//Sad//Sad1696.wav
# D://Datasets//TRAINING//padded//Sad//Sad1697.wav
# D://Datasets//TRAINING//padded//Sad//Sad1698.wav
# D://Datasets//TRAINING//padded//Sad//Sad1699.wav
# D://Datasets//TRAINING//padded//Sad//Sad1700.wav
# D://Datasets//TRAINING//padded//Sad//Sad1701.wav
# D://Datasets//TRAINING//padded//Sad//Sad1702.wav
# D://Datasets//TRAINING//padded//Sad//Sad1703.wav
# D://Datasets//TRAINING//padded//Sad//Sad1704.wav
# D://Datasets//TRAINING//padded//Sad//Sad1705.wav
# D://Datasets//TRAINING//padded//Sad//Sad1706.wav
# D://Datasets//TRAINING//padded//Sad//Sad1707.wav
# D://Datasets//TRAINING//padded//Sad//Sad1708.wav
# D://Datasets//TRAINING//padded//Sad//Sad1709.wav
# D://Datasets//TRAINING//padded//Sad//Sad1710.wav
# D://Datasets//TRAINING//padded//Sad//Sad1711.wav
# D://Datasets//TRAINING//padded//Sad//Sad1712.wav
# D://Datasets//TRAINING//padded//Sad//Sad1713.wav
# D://Datasets//TRAINING//padded//Sad//Sad1714.wav
# D://Datasets//TRAINING//padded//Sad//Sad1715.wav
# D://Datasets//TRAINING//padded//Sad//Sad1716.wav
# D://Datasets//TRAINING//padded//Sad//Sad1717.wav
# D://Datasets//TRAINING//padded//Sad//Sad1718.wav
# D://Datasets//TRAINING//padded//Sad//Sad1719.wav
# D://Datasets//TRAINING//padded//Sad//Sad1720.wav
# D://Datasets//TRAINING//padded//Sad//Sad1721.wav
# D://Datasets//TRAINING//padded//Sad//Sad1722.wav
# D://Datasets//TRAINING//padded//Sad//Sad1723.wav
# D://Datasets//TRAINING//padded//Sad//Sad1724.wav
# D://Datasets//TRAINING//padded//Sad//Sad1725.wav
# D://Datasets//TRAINING//padded//Sad//Sad1726.wav
# D://Datasets//TRAINING//padded//Sad//Sad1727.wav
# D://Datasets//TRAINING//padded//Sad//Sad1728.wav
# D://Datasets//TRAINING//padded//Sad//Sad1729.wav
# D://Datasets//TRAINING//padded//Sad//Sad1730.wav
# D://Datasets//TRAINING//padded//Sad//Sad1731.wav
# D://Datasets//TRAINING//padded//Sad//Sad1732.wav
# D://Datasets//TRAINING//padded//Sad//Sad1733.wav
# D://Datasets//TRAINING//padded//Sad//Sad1734.wav
# D://Datasets//TRAINING//padded//Sad//Sad1735.wav
# D://Datasets//TRAINING//padded//Sad//Sad1736.wav
# D://Datasets//TRAINING//padded//Sad//Sad1737.wav
# D://Datasets//TRAINING//padded//Sad//Sad1738.wav
# D://Datasets//TRAINING//padded//Sad//Sad1739.wav
# D://Datasets//TRAINING//padded//Sad//Sad1740.wav
# D://Datasets//TRAINING//padded//Sad//Sad1741.wav
# D://Datasets//TRAINING//padded//Sad//Sad1742.wav
# D://Datasets//TRAINING//padded//Sad//Sad1743.wav
# D://Datasets//TRAINING//padded//Sad//Sad1744.wav
# D://Datasets//TRAINING//padded//Sad//Sad1745.wav
# D://Datasets//TRAINING//padded//Sad//Sad1746.wav
# D://Datasets//TRAINING//padded//Sad//Sad1747.wav
# D://Datasets//TRAINING//padded//Sad//Sad1748.wav
# D://Datasets//TRAINING//padded//Sad//Sad1749.wav
# D://Datasets//TRAINING//padded//Sad//Sad1750.wav
# D://Datasets//TRAINING//padded//Sad//Sad1751.wav
# D://Datasets//TRAINING//padded//Sad//Sad1752.wav
# D://Datasets//TRAINING//padded//Sad//Sad1753.wav
# D://Datasets//TRAINING//padded//Sad//Sad1754.wav
# D://Datasets//TRAINING//padded//Sad//Sad1755.wav
# D://Datasets//TRAINING//padded//Sad//Sad1756.wav
# D://Datasets//TRAINING//padded//Sad//Sad1757.wav
# D://Datasets//TRAINING//padded//Sad//Sad1758.wav
# D://Datasets//TRAINING//padded//Sad//Sad1759.wav
# D://Datasets//TRAINING//padded//Sad//Sad1760.wav
# D://Datasets//TRAINING//padded//Sad//Sad1761.wav
# D://Datasets//TRAINING//padded//Sad//Sad1762.wav
# D://Datasets//TRAINING//padded//Sad//Sad1763.wav
# D://Datasets//TRAINING//padded//Sad//Sad1764.wav
# D://Datasets//TRAINING//padded//Sad//Sad1765.wav
# D://Datasets//TRAINING//padded//Sad//Sad1766.wav
# D://Datasets//TRAINING//padded//Sad//Sad1767.wav
# D://Datasets//TRAINING//padded//Sad//Sad1768.wav
# D://Datasets//TRAINING//padded//Sad//Sad1769.wav
# D://Datasets//TRAINING//padded//Sad//Sad1770.wav
# D://Datasets//TRAINING//padded//Sad//Sad1771.wav
# D://Datasets//TRAINING//padded//Sad//Sad1772.wav
# D://Datasets//TRAINING//padded//Sad//Sad1773.wav
# D://Datasets//TRAINING//padded//Sad//Sad1774.wav
# D://Datasets//TRAINING//padded//Sad//Sad1775.wav
# D://Datasets//TRAINING//padded//Sad//Sad1776.wav
# D://Datasets//TRAINING//padded//Sad//Sad1777.wav
# D://Datasets//TRAINING//padded//Sad//Sad1778.wav
# D://Datasets//TRAINING//padded//Sad//Sad1779.wav
# D://Datasets//TRAINING//padded//Sad//Sad1780.wav
# D://Datasets//TRAINING//padded//Sad//Sad1781.wav
# D://Datasets//TRAINING//padded//Sad//Sad1782.wav
# D://Datasets//TRAINING//padded//Sad//Sad1783.wav
# D://Datasets//TRAINING//padded//Sad//Sad1784.wav
# D://Datasets//TRAINING//padded//Sad//Sad1785.wav
# D://Datasets//TRAINING//padded//Sad//Sad1786.wav
# D://Datasets//TRAINING//padded//Sad//Sad1787.wav
# D://Datasets//TRAINING//padded//Sad//Sad1788.wav
# D://Datasets//TRAINING//padded//Sad//Sad1789.wav
# D://Datasets//TRAINING//padded//Sad//Sad1790.wav
# D://Datasets//TRAINING//padded//Sad//Sad1791.wav
# D://Datasets//TRAINING//padded//Sad//Sad1792.wav

# %%
def change_amplitude(emotionfile, d1, newSoundFile, d2):
    
    if d1 <= d2:
        sound = AudioSegment.from_file(emotionfile) - np.random.randint(0, (6 * d2/d1 - 1))
        sound.export(newSoundFile, format='wav')  ### save the new generated file in a folder
    else:
        print('Invalid distance parameters. d1 should be <= d2.')

# %%
def change_amplitude_range(emotionfile, newSoundFile, threshold):
    #amount = np.random.randint(0, threshold)
    amount = random.uniform(0, threshold)
    #print('Deamplify ' + str(emotionfile) + ' by ' + str(amount) + ' db.')
    sound = AudioSegment.from_file(emotionfile) - amount
    sound.export(newSoundFile, format='wav')  ### save the new generated file in a folder
    return amount

# %%
'''
def deamplify_per_folder(directory):
    for file in os.listdir(directory):
        if file.endswith('.wav'):
            soundFile = directory + file
            newSoundFile = directory + 'deamplified_' + file
            change_amplitude_range(soundFile, newSoundFile, 12)
'''
# Out:
# "\ndef deamplify_per_folder(directory):\n    for file in os.listdir(directory):\n        if file.endswith('.wav'):\n            soundFile = directory + file\n            newSoundFile = directory + 'deamplified_' + file\n            change_amplitude_range(soundFile, newSoundFile, 12)\n"

# %%
'''
for directory in emotion_train_folders:
    deamplify_per_folder(directory)
    
for directory in emotion_test_folders:
    deamplify_per_folder(directory)
'''
# Out:
# '\nfor directory in emotion_train_folders:\n    deamplify_per_folder(directory)\n    \nfor directory in emotion_test_folders:\n    deamplify_per_folder(directory)\n'

# %%
def add_noise_per_file(emotionfile, bgnoise, newSoundFile):
    
    emotionsound = AudioSegment.from_wav(emotionfile)
    emotion_duration = emotionsound.duration_seconds * 1000
    noise = AudioSegment.from_wav(bgnoise)
    noise_duration = noise.duration_seconds * 1000
    
    threshold = noise_duration - emotion_duration
    
    if threshold > 0:
        overlay_start = np.random.randint(0, threshold)
    else:
        overlay_start = 0
        
    targeted_chunk = noise[overlay_start:overlay_start + emotion_duration]
    newSound = emotionsound.overlay(targeted_chunk, position=0)
    newSound=newSound[0:5000]
    newSound.export(newSoundFile, format='wav')  ### save the new generated file in a folder

# %%
def add_noise_and_deamplify_per_folder(directory, extension, noise_directory):
    for file in os.listdir(directory):
        if file.endswith(extension) and not file[1] == '_':
            for i in range(0, 2):
                soundFile = directory + file
                amount = change_amplitude_range(soundFile, soundFile, 12)
                noise = random.choice(os.listdir(noise_directory))
                random_noise = noise_directory + noise
                newSoundFile = directory + 'deamp_' + str(amount) + '_noise_' + noise[:len(noise)-5] + '_' + file
                add_noise_per_file(soundFile, random_noise, newSoundFile)
                print(newSoundFile)

# %%
n_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised//Neutral//'
s_directory_all = 'D://Datasets//TRAINING//padded_deamplified_allnoised//Sad//'

n_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised//Neutral//'
s_directory_home = 'D://Datasets//TRAINING//padded_deamplified_homenoised//Sad//'

add_noise_and_deamplify_per_folder(n_directory_all, 'wav', background_noise_all)
add_noise_and_deamplify_per_folder(s_directory_all, 'wav', background_noise_all)
add_noise_and_deamplify_per_folder(n_directory_home, 'wav', background_noise_home)

# %%
'''
percent = 0.2
partition_directory(h_directory, h_test, percent)
partition_directory(a_directory, a_test, percent)
partition_directory(n_directory, n_test, percent)
partition_directory(s_directory, s_test, percent)
partition_directory(o_directory, o_test, percent)
'''

# %%
# AudioEffectsChain().reverb()(infile, outfile)
