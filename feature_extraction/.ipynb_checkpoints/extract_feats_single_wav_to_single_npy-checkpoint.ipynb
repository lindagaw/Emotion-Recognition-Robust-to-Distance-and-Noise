# %%
import random
import time
import datetime
import numpy as np
from numpy import array
import pandas as pd
from pydub import AudioSegment
import os
import shutil
import glob
import gc
import sys
import h5py
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier

#imported for testing
import wave
import contextlib

# for outputing file
import scipy.stats.stats as st

from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import normalize
from sklearn.neighbors import KNeighborsClassifier
from scipy.cluster.vq import vq, kmeans, whiten
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from sklearn import mixture
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.impute import SimpleImputer
import pickle
import librosa
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.datasets.samples_generator import make_blobs
from sklearn.metrics import auc, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from pandas.plotting import parallel_coordinates
import pickle

from keras.layers import Convolution1D, Dense, MaxPooling1D, Flatten
from keras.constraints import maxnorm
from keras.layers import Add
from keras.models import Sequential
from keras.layers import Dense, Add
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.layers import Dropout, Input
from keras.callbacks import EarlyStopping
from keras.layers import Activation
from keras.utils import np_utils
from keras.utils import to_categorical

from IPython.display import clear_output

import warnings

warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

sample_rate = 44100
hop_length = 441  # frame size= 2 * hop
segment_length = int(sample_rate * 0.2)  # 0.2
segment_pad = int(sample_rate * 0.02)  # 0.02
overlapping = int(sample_rate * 0.1)  # 0.1

NumofFeaturetoUse = 272
frame_number = 48

try:
    NumofFeaturetoUse = int(sys.argv[1])
    print('Number of features to use is set to ' + str(sys.argv[1]))
except:
    print('Number of features are unspecified. Defaut is set to = 272.')
# Out:
# Number of features are unspecified. Defaut is set to = 272.

# %%
def update_progress(progress):
    bar_length = 100
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1
    block = int(round(bar_length * progress))
    clear_output(wait=True)
    text = "Progress: [{0}] {1:.1f}%".format(
        "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)


def str_to_int(input_np):
    output_np = []
    for x in np.nditer(input_np):
        if x == 'H':
            x = 0
        elif x == 'A':
            x = 1
        elif x == 'N':
            x = 2
        else:
            x = 3
        output_np.append(x)
    output_np = np.array(output_np)
    output_np = np.reshape(output_np, (len(output_np), 1))
    return output_np


def float_compatible(input_np):
    input_np = np.nan_to_num(input_np)
    x = np.where(input_np >= np.finfo(np.float32).max)
    for index in range(0, len(x[0])):
        try:
            x_position = x[0][index]
            y_position = x[1][index]
            input_np[x_position, y_position] = 0.0
        except:
            print(x)
            print(x[0])
    return input_np


def function_FeatureExtractfromSinglewindow(y, hop_length, sr):
    genFeatures = np.array([])

    mfcc0 = librosa.feature.mfcc(
        y=y, sr=sr, n_fft=hop_length*2, hop_length=hop_length, n_mfcc=13)
    mfcc = np.transpose(mfcc0)
    genFeatures = np.hstack((genFeatures, np.amin(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, np.median(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, np.std(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, np.var(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(mfcc, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(mfcc, 0)))
    #print(genFeatures.shape)

    mfcc_delta = librosa.feature.delta(mfcc0)
    mfcc_delta = np.transpose(mfcc_delta)
    genFeatures = np.hstack((genFeatures, np.amin(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.median(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.std(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.var(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(mfcc_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(mfcc_delta, 0)))
    #print(genFeatures.shape)

    zcr0 = librosa.feature.zero_crossing_rate(
        y=y, frame_length=hop_length*2, hop_length=hop_length)
    zcr = np.transpose(zcr0)
    genFeatures = np.hstack((genFeatures, np.amin(zcr, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(zcr, 0)))
    genFeatures = np.hstack((genFeatures, np.median(zcr, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(zcr, 0)))
    genFeatures = np.hstack((genFeatures, np.std(zcr, 0)))
    genFeatures = np.hstack((genFeatures, np.var(zcr, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(zcr, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(zcr, 0)))
    #print(genFeatures.shape)

    zcr_delta = librosa.feature.delta(zcr0)
    zcr_delta = np.transpose(zcr_delta)
    genFeatures = np.hstack((genFeatures, np.amin(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.median(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.std(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.var(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(zcr_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(zcr_delta, 0)))
    #print(genFeatures.shape)

    Erms0 = librosa.feature.rms(
        y=y, frame_length=hop_length*2, hop_length=hop_length)
    Erms = np.transpose(Erms0)
    genFeatures = np.hstack((genFeatures, np.amin(Erms, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(Erms, 0)))
    genFeatures = np.hstack((genFeatures, np.median(Erms, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(Erms, 0)))
    genFeatures = np.hstack((genFeatures, np.std(Erms, 0)))
    genFeatures = np.hstack((genFeatures, np.var(Erms, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(Erms, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(Erms, 0)))
    #print(genFeatures.shape)

    Erms_delta = librosa.feature.delta(Erms0)
    Erms_delta = np.transpose(Erms_delta)
    genFeatures = np.hstack((genFeatures, np.amin(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.median(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.std(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.var(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(Erms_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(Erms_delta, 0)))
    #print(genFeatures.shape)

    cent0 = librosa.feature.spectral_centroid(
        y=y, sr=sr, n_fft=hop_length*2, hop_length=hop_length)
    cent = np.transpose(cent0)
    genFeatures = np.hstack((genFeatures, np.amin(cent, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(cent, 0)))
    genFeatures = np.hstack((genFeatures, np.median(cent, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(cent, 0)))
    genFeatures = np.hstack((genFeatures, np.std(cent, 0)))
    genFeatures = np.hstack((genFeatures, np.var(cent, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(cent, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(cent, 0)))
    #print(genFeatures.shape)

    cent_delta = librosa.feature.delta(cent0)
    cent_delta = np.transpose(cent_delta)
    genFeatures = np.hstack((genFeatures, np.amin(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.median(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.std(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.var(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(cent_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(cent_delta, 0)))
    #print(genFeatures.shape)
    #Each frame of a magnitude spectrogram is normalized and treated as a distribution over frequency bins, from which the mean (centroid) is extracted per frame.

    ############### pitch at certain frame
    pitches, magnitudes = librosa.core.piptrack(
        y=y, sr=sr, fmin=75, fmax=8000, n_fft=hop_length*2, hop_length=hop_length)
    p = [pitches[magnitudes[:, i].argmax(), i]for i in range(0, pitches.shape[1])]
    pitch0 = np.array(p)  # shape (305,)
    pitch = np.transpose(pitch0)
    genFeatures = np.hstack((genFeatures, np.amin(pitch, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(pitch, 0)))
    genFeatures = np.hstack((genFeatures, np.median(pitch, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(pitch, 0)))
    genFeatures = np.hstack((genFeatures, np.std(pitch, 0)))
    genFeatures = np.hstack((genFeatures, np.var(pitch, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(pitch, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(pitch, 0)))
    #print(genFeatures.shape)

    pitch_delta = librosa.feature.delta(pitch0)
    pitch_delta = np.transpose(pitch_delta)
    genFeatures = np.hstack((genFeatures, np.amin(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.amax(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.median(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.mean(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.std(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, np.var(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.skew(pitch_delta, 0)))
    genFeatures = np.hstack((genFeatures, st.kurtosis(pitch_delta, 0)))

    #print(genFeatures.shape)    #272
    return genFeatures

# %%
# Extract specified amount of features from an audio file
def extract_feats_single_wav(npy_path, audiofile):
    flag_start_all = 0
    All = np.array([])
    audio, s_rate = librosa.load(audiofile, sr=sample_rate)
    segment_start_flag = 0
    start_seg = 0
    while(start_seg + segment_length) < len(audio):
        sound_window = audio[start_seg:(start_seg + segment_length)]
        featureSet = function_FeatureExtractfromSinglewindow(
            sound_window, hop_length, s_rate)
        if segment_start_flag == 0:
            SegAllFeat = featureSet
            segment_start_flag = 1
        else:
            SegAllFeat = np.vstack((SegAllFeat, featureSet))
        start_seg = start_seg + overlapping
    
    SegAllFeat = float_compatible(SegAllFeat)
    SegAllFeat = normalize(SegAllFeat, norm='l2', axis=0)

    if flag_start_all == 0:
        All = SegAllFeat
        flag_start_all = 1
    else:
        All = np.vstack((All, SegAllFeat))
    
    audio_npy = (audiofile[:len(audiofile)-4] + '.npy').split('//')[len((audiofile[:len(audiofile)-4] + '.npy').split('//'))-1]
    audio_npy = npy_path + audio_npy
    All = float_compatible(All)
    
    if str(All.shape) == '(48, 272)':
        np.save(audio_npy, All)
        print('saved ' + audio_npy)
    else:
        print('error ' + audio_npy)
    
    return All

# %%
homenoised_happy = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Happy//'
homenoised_angry = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Angry//'
homenoised_neutral = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Neutral//'
homenoised_sad = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Sad//'
homenoised_other = 'D://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//Other//'

homenoised_calm = 'F://Datasets//TRAINING (sound)//padded_deamplified_homenoised_reverberated//Calm//'
homenoised_surprise = 'F://Datasets//TRAINING (sound)//padded_deamplified_homenoised_reverberated//Surprise//'

homenoised_calm_npy = 'F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//'
homenoised_surprise_npy = 'F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Surprise_npy//'

#homenoised = [homenoised_happy, homenoised_angry, homenoised_neutral, homenoised_sad, homenoised_other]
homenoised = [homenoised_calm, homenoised_surprise]
homenoised_npy = [homenoised_calm_npy, homenoised_surprise_npy]

# %%
elapsed = []
for index in [0, 1]:
    for audio in os.listdir(homenoised[index]):
        npy_title = homenoised_npy[index] + audio[:len(audio)-4] + '.npy'
        try:
            if os.path.isfile(npy_title):
                print(npy_title + 'already exists. Skipping...')
                continue
            elif not audio.endswith('.wav') or audio[0] == '.':
                continue
            else:
                audio = homenoised[index] + audio
                start = time.time()
                extract_feats_single_wav(homenoised_npy[index], audio)
                end = time.time()
                elapsed.append(end-start)
        except Exception as e:
            print(e)
# Out:
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm0.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm1.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm3.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm5.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm7.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm8.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm9.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm10.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm11.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm12.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm13.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm14.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm15.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm16.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm17.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm18.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm19.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm20.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm21.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm22.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm23.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm24.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm25.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm26.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm27.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm28.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm29.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm30.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm31.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm32.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm33.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm34.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm35.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm36.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm37.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm38.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm39.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm40.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm41.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm42.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm43.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm44.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm45.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm46.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm47.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm48.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm49.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm50.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm51.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm52.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm53.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm54.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm55.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm56.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm57.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm58.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm59.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm60.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm61.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm62.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm63.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm64.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm65.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm66.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm67.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm68.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm69.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm70.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm71.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm72.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm73.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm74.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm75.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm76.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm77.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm78.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm79.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm80.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm81.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm82.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm83.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm84.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm85.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm86.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm87.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm88.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm89.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm90.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm91.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm92.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm93.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm94.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm95.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm96.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm97.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm98.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm99.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm100.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm101.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm102.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm103.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm104.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm105.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm106.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm107.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm108.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm109.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm110.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm111.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm112.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm113.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm114.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm115.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm116.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm117.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm118.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm119.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm120.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm121.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm122.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm123.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm124.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm125.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm126.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm127.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm128.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm129.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm130.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm131.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm132.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm133.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm134.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm135.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm136.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm137.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm138.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm139.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm140.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm141.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm142.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm143.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm144.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm145.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm146.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm147.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm148.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm149.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm150.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm151.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm152.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm153.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm154.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm155.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm156.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm157.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm158.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm159.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm160.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm161.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm162.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm163.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm164.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm165.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm166.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm167.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm168.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm169.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm170.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm171.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm172.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm173.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm174.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm175.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm176.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm177.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm178.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm179.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm180.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm181.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm182.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm183.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm184.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm185.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm186.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm187.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm188.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm189.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm190.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//Calm191.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.159927816760522_noise_home_80_Calm0.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.712123816572998_noise_home_23_Calm0.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.767105060066474_noise_home_24_Calm1.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.751628702832617_noise_home_23_Calm1.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.413732351014086_noise_home_81_Calm2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.097486831745998_noise_home_23_Calm2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.9836700822735018_noise_home_81_Calm3.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.923737076491744_noise_home_26_Calm3.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.358176722599648_noise_home_22_Calm4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.8650932408773215_noise_home_23_Calm4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.20995957530636_noise_home_80_Calm5.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.728033153006505_noise_home_80_Calm5.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3917150485023826_noise_home_82_Calm6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.440224931226606_noise_home_2_Calm6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.126834273542546_noise_home_23_Calm7.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.093040872558847_noise_home_81_Calm7.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.842089244170486_noise_home_82_Calm8.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.610118592156769_noise_home_88_Calm8.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.014182751200229_noise_home_88_Calm9.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.1026849293533267_noise_home_82_Calm9.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.336723843025275_noise_home_23_Calm10.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.640564859535312_noise_home_80_Calm10.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.14878882570837293_noise_home_83_Calm11.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.210602665932689_noise_home_24_Calm11.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8696318540923396_noise_home_80_Calm12.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.665594026679688_noise_home_2_Calm12.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.3158985481873895_noise_home_22_Calm13.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.9206177453662208_noise_home_26_Calm13.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9004084095747196_noise_home_82_Calm14.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.863198670455112_noise_home_24_Calm14.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.193898400106084_noise_home_22_Calm15.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.116812364086904_noise_home_27_Calm15.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.428293450865405_noise_home_82_Calm16.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.8073726371625662_noise_home_81_Calm16.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.648107670800536_noise_home_24_Calm17.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.8219953884307305_noise_home_24_Calm17.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.321636911418851_noise_home_2_Calm18.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.928248522388848_noise_home_80_Calm18.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.2937498651322623_noise_home_80_Calm19.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.299774544974973_noise_home_83_Calm19.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.358194875906939_noise_home_25_Calm20.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.705769381799335_noise_home_81_Calm20.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.2433099392981948_noise_home_23_Calm21.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.211150492813749_noise_home_25_Calm21.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.04521777966734675_noise_home_88_Calm22.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.519330340562714_noise_home_22_Calm22.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.321724249926906_noise_home_88_Calm23.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.709788338378885_noise_home_82_Calm23.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.582750769341554_noise_home_81_Calm24.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.951351166287882_noise_home_2_Calm24.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.3189101610419627_noise_home_26_Calm25.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.654247497324608_noise_home_24_Calm25.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.594848328527613_noise_home_82_Calm26.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.4127189432965159_noise_home_25_Calm26.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.183932861553645_noise_home_80_Calm27.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.015044216828257_noise_home_2_Calm27.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.210944334275817_noise_home_82_Calm28.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3413510865093947_noise_home_83_Calm28.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.242548301453887_noise_home_82_Calm29.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.872045797681434_noise_home_2_Calm29.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.919621304072708_noise_home_83_Calm30.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.06371860715923106_noise_home_23_Calm30.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.591081227257153_noise_home_23_Calm31.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.833022811612814_noise_home_26_Calm31.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.07303654381397_noise_home_23_Calm32.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.247459359047902_noise_home_2_Calm32.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.9216896254393658_noise_home_2_Calm33.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.2723186966942053_noise_home_2_Calm33.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.000321024421265_noise_home_23_Calm34.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.168037487779802_noise_home_81_Calm34.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.774360987571485_noise_home_23_Calm35.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.0998487241947275_noise_home_22_Calm35.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.308974917493725_noise_home_26_Calm36.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.991057604392864_noise_home_23_Calm36.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.324337533677873_noise_home_25_Calm37.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.96230140732895_noise_home_80_Calm37.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.076565354448437_noise_home_2_Calm38.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.848821823039694_noise_home_82_Calm38.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.3267904208726_noise_home_80_Calm39.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.2031324681241196_noise_home_83_Calm39.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.23730806283356_noise_home_23_Calm40.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.76543241693626_noise_home_80_Calm40.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.867290407363651_noise_home_26_Calm41.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.112441926634958_noise_home_80_Calm41.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.2114618376252295_noise_home_2_Calm42.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.203037310281774_noise_home_2_Calm42.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.7755673932671696_noise_home_82_Calm43.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.919953250028309_noise_home_23_Calm43.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.43473463875602_noise_home_81_Calm44.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.693624758398778_noise_home_23_Calm44.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.154966121851391_noise_home_83_Calm45.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.6901082786850488_noise_home_25_Calm45.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.611836049065626_noise_home_26_Calm46.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.052890493938197_noise_home_23_Calm46.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.107879218347718_noise_home_2_Calm47.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.7514997701617134_noise_home_22_Calm47.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.8310897337745344_noise_home_88_Calm48.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.887691824606904_noise_home_80_Calm48.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.8118673956902218_noise_home_25_Calm49.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.538578233645476_noise_home_23_Calm49.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.6753679443090204_noise_home_25_Calm50.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.816336566578677_noise_home_23_Calm50.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.289532458039094_noise_home_24_Calm51.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.9302205066124936_noise_home_81_Calm51.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.563168218387923_noise_home_24_Calm52.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.352141226934722_noise_home_81_Calm52.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.31185228147978_noise_home_24_Calm53.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.0395382615850597_noise_home_22_Calm53.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.435850020095137_noise_home_25_Calm54.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.9134615790829734_noise_home_23_Calm54.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.4827990045955457_noise_home_83_Calm55.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.7702995854468586_noise_home_2_Calm55.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.686926663001411_noise_home_26_Calm56.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.9277243492702545_noise_home_26_Calm56.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.177758685389039_noise_home_88_Calm57.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.114401984314403_noise_home_81_Calm57.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.217209979070159_noise_home_22_Calm58.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.7859555853726712_noise_home_80_Calm58.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.331427689792445_noise_home_88_Calm59.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.923148875878593_noise_home_82_Calm59.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.509156638924684_noise_home_2_Calm60.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.856091931345368_noise_home_2_Calm60.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.398159279321076_noise_home_82_Calm61.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.830767136754926_noise_home_81_Calm61.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.2151058527978478_noise_home_24_Calm62.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.0266407274952707_noise_home_24_Calm62.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.534292656994683_noise_home_26_Calm63.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.18213624063496825_noise_home_23_Calm63.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.7693194853134857_noise_home_82_Calm64.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.278916351714631_noise_home_2_Calm64.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.676661651327686_noise_home_88_Calm65.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.833267554553371_noise_home_82_Calm65.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.71067386029533_noise_home_80_Calm66.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.37692818641244_noise_home_83_Calm66.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.1551459573586422_noise_home_82_Calm67.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3033837126259513_noise_home_81_Calm67.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.2082742873432224_noise_home_27_Calm68.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.321472223754007_noise_home_88_Calm68.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.911681204454597_noise_home_23_Calm69.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.544956114097042_noise_home_27_Calm69.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.5728760511548145_noise_home_2_Calm70.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.921366505864346_noise_home_81_Calm70.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.948295850391114_noise_home_2_Calm71.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.588294846561325_noise_home_80_Calm71.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.54598648872626_noise_home_81_Calm72.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.454684673473281_noise_home_23_Calm72.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.2179653096892014_noise_home_26_Calm73.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.5089705292409406_noise_home_81_Calm73.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8836796749946267_noise_home_80_Calm74.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.4513723157257039_noise_home_81_Calm74.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.776143536152354_noise_home_81_Calm75.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.028318045734014_noise_home_80_Calm75.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.99306465392155_noise_home_82_Calm76.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.368071458983925_noise_home_23_Calm76.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.818182224037083_noise_home_82_Calm77.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.790340425759057_noise_home_23_Calm77.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.268908286476446_noise_home_80_Calm78.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.491175014017294_noise_home_26_Calm78.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.245250015615778_noise_home_80_Calm79.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.5860934094673578_noise_home_80_Calm79.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.262686907241777_noise_home_24_Calm80.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.388086861523418_noise_home_2_Calm80.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.4080054560005522_noise_home_80_Calm81.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.5060108513557089_noise_home_23_Calm81.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.03005447006894_noise_home_82_Calm82.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.069613875686249_noise_home_27_Calm82.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.652725039352882_noise_home_27_Calm83.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8251355236618694_noise_home_25_Calm83.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.5119669191172616_noise_home_2_Calm84.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.469468054168656_noise_home_26_Calm84.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.257801698021877_noise_home_80_Calm85.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.760435909946043_noise_home_27_Calm85.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.423586623589088_noise_home_2_Calm86.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.368635462066481_noise_home_2_Calm86.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.486847860248803_noise_home_83_Calm87.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8550267565034475_noise_home_82_Calm87.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.789911415486266_noise_home_82_Calm88.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.19763863608231_noise_home_22_Calm88.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.88208026889467_noise_home_88_Calm89.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.3323145908605842_noise_home_24_Calm89.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.630778652870758_noise_home_24_Calm90.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_4.552648599293786_noise_home_80_Calm90.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.0821804293004935_noise_home_23_Calm91.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.153316292201783_noise_home_83_Calm91.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.9538450423229174_noise_home_24_Calm92.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.98585588226941_noise_home_22_Calm92.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.483869542715002_noise_home_27_Calm93.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.020519630318974_noise_home_23_Calm93.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.87846527564167_noise_home_81_Calm94.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_6.8254599683288095_noise_home_2_Calm94.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.522228306284786_noise_home_80_Calm95.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.862141493651073_noise_home_22_Calm95.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_7.558124475911418_noise_home_83_Calm96.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.717272525506944_noise_home_82_Calm96.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.344163504062493_noise_home_22_Calm97.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_8.734304594044438_noise_home_81_Calm97.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.5814881853408_noise_home_81_Calm98.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.660886059268217_noise_home_2_Calm98.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_1.7650182653463822_noise_home_80_Calm99.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_0.47855120284969344_noise_home_83_Calm99.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.143785084892046_noise_home_81_Calm100.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9919874323680884_noise_home_80_Calm100.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.570434510054648_noise_home_83_Calm101.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_5.076899126760006_noise_home_26_Calm101.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9706349464796613_noise_home_83_Calm102.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.86317891578683_noise_home_2_Calm102.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.212961317268023_noise_home_26_Calm103.npy
# ...
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_10.98585588226941_noise_home_22_Calm92_WetDry_2_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.566578876167274_noise_home_80_Calm154_WetDry_6_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.000321024421265_noise_home_23_Calm34_WetDry_4_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.585134521852225_noise_home_23_Calm108_WetDry_4_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.028318045734014_noise_home_80_Calm75_WetDry_8_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.654247497324608_noise_home_24_Calm25_WetDry_4_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.03005447006894_noise_home_82_Calm82_WetDry_2_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.654712454271921_noise_home_80_Calm186_WetDry_2_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.076565354448437_noise_home_2_Calm38_WetDry_6_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.678254538723618_noise_home_2_Calm158_WetDry_4_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.112441926634958_noise_home_80_Calm41_WetDry_2_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.682932175145423_noise_home_2_Calm177_WetDry_2_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.114401984314403_noise_home_81_Calm57_WetDry_6_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.70236202323099_noise_home_82_Calm146_WetDry_8_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.168037487779802_noise_home_81_Calm34_WetDry_6_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.705769381799335_noise_home_81_Calm20_WetDry_2_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.211150492813749_noise_home_25_Calm21_WetDry_6_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.728033153006505_noise_home_80_Calm5_WetDry_4_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.278916351714631_noise_home_2_Calm64_WetDry_4_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.736865612079393_noise_home_81_Calm175_WetDry_4_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.308974917493725_noise_home_26_Calm36_WetDry_2_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.751628702832617_noise_home_23_Calm1_WetDry_8_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.321472223754007_noise_home_88_Calm68_WetDry_2_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.816336566578677_noise_home_23_Calm50_WetDry_8_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.358176722599648_noise_home_22_Calm4_WetDry_6_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.833267554553371_noise_home_82_Calm65_WetDry_8_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.358194875906939_noise_home_25_Calm20_WetDry_6_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.842089244170486_noise_home_82_Calm8_WetDry_4_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.368071458983925_noise_home_23_Calm76_WetDry_2_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.862141493651073_noise_home_22_Calm95_WetDry_6_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.39571303172775_noise_home_80_Calm158_WetDry_6_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.86317891578683_noise_home_2_Calm102_WetDry_2_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.420156688464974_noise_home_80_Calm140_WetDry_6_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.872045797681434_noise_home_2_Calm29_WetDry_4_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.43473463875602_noise_home_81_Calm44_WetDry_6_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.896901122145263_noise_home_88_Calm147_WetDry_8_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.475299661497647_noise_home_83_Calm143_WetDry_8_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.951351166287882_noise_home_2_Calm24_WetDry_2_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.5814881853408_noise_home_81_Calm98_WetDry_6_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.958115123050247_noise_home_83_Calm164_WetDry_6_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.588294846561325_noise_home_80_Calm71_WetDry_6_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_9.960189300502275_noise_home_27_Calm104_WetDry_8_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.59496754071962_noise_home_88_Calm104_WetDry_8_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.611836049065626_noise_home_26_Calm46_WetDry_2_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.712123816572998_noise_home_23_Calm0_WetDry_4_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.749600708571949_noise_home_88_Calm190_WetDry_8_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.782710143323833_noise_home_82_Calm160_WetDry_4_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.802124087693986_noise_home_22_Calm145_WetDry_8_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.856091931345368_noise_home_2_Calm60_WetDry_4_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.863198670455112_noise_home_24_Calm14_WetDry_6_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.919621304072708_noise_home_83_Calm30_WetDry_2_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.959775852854698_noise_home_81_Calm169_WetDry_6_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.961477867458918_noise_home_25_Calm144_WetDry_2_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_11.99306465392155_noise_home_82_Calm76_WetDry_4_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.0821804293004935_noise_home_23_Calm91_WetDry_4_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.0998487241947275_noise_home_22_Calm35_WetDry_2_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.1400781385903596_noise_home_23_Calm129_WetDry_8_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.257801698021877_noise_home_80_Calm85_WetDry_6_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.289532458039094_noise_home_24_Calm51_WetDry_2_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.295467400737325_noise_home_23_Calm185_WetDry_2_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3033837126259513_noise_home_81_Calm67_WetDry_6_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3355852260918897_noise_home_88_Calm155_WetDry_6_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3413510865093947_noise_home_83_Calm28_WetDry_2_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.368635462066481_noise_home_2_Calm86_WetDry_6_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.37692818641244_noise_home_83_Calm66_WetDry_4_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.3917150485023826_noise_home_82_Calm6_WetDry_8_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.4252133175013757_noise_home_2_Calm136_WetDry_8_DecayFactor_4_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.4373520793806573_noise_home_25_Calm189_WetDry_2_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.5028229079774724_noise_home_81_Calm121_WetDry_2_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.522228306284786_noise_home_80_Calm95_WetDry_6_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.5409767360899402_noise_home_25_Calm163_WetDry_8_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.652725039352882_noise_home_27_Calm83_WetDry_6_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.660886059268217_noise_home_2_Calm98_WetDry_6_DecayFactor_6_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.6888957365042825_noise_home_83_Calm127_WetDry_4_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.6982506090779057_noise_home_2_Calm156_WetDry_6_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.7755673932671696_noise_home_82_Calm43_WetDry_8_DecayFactor_2_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.818681087041412_noise_home_82_Calm155_WetDry_6_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8251355236618694_noise_home_25_Calm83_WetDry_6_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8550267565034475_noise_home_82_Calm87_WetDry_6_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8696318540923396_noise_home_80_Calm12_WetDry_2_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8784909352554937_noise_home_83_Calm167_WetDry_2_DecayFactor_2_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8822924506852576_noise_home_81_Calm150_WetDry_8_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.8836796749946267_noise_home_80_Calm74_WetDry_2_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9004084095747196_noise_home_82_Calm14_WetDry_8_DecayFactor_4_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9473702115371254_noise_home_81_Calm146_WetDry_2_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9706349464796613_noise_home_83_Calm102_WetDry_6_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9764077381032674_noise_home_25_Calm127_WetDry_8_DecayFactor_6_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.978527240480625_noise_home_82_Calm153_WetDry_4_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_2.9919874323680884_noise_home_80_Calm100_WetDry_4_DecayFactor_2_Diffusion_2.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.021928510304422_noise_home_25_Calm169_WetDry_2_DecayFactor_6_Diffusion_4.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.0266407274952707_noise_home_24_Calm62_WetDry_6_DecayFactor_4_Diffusion_6.npy
# saved F://Datasets//TRAINING//padded_deamplified_homenoised_reverberated//npy//Calm_npy//deamp_3.1026849293533267_noise_home_82_Calm9_WetDry_8_DecayFactor_6_Diffusion_6.npy

# %%
print(len(elapsed))

# %%
print(np.mean(elapsed))
